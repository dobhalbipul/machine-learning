# %% [markdown]
# # Module 2: Supervised Learning - Regression
#
# ### Demo 1: Linear Regression Using Python
#
# In this demo, you will be building a simple Linear Regression Model.

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# Given the dataset set of advertising Predict sales based on TV ads

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>Import required libraries</h3></li></ul>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, SGDRegressor
import statsmodels.api as sm

# %% [markdown]
# ## Dataset

# %% [markdown]
# The dataset contains various adversting medias and their respective sales

# %% [markdown]
# - <b>TV:</b> Adversting in TV
# - <b>radio:</b> Advertising in radio
# - <b>newspaper:</b> Advertising in newspaper

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>Read the data from the csv file</h3></li></ul>
# </div>

# %%
data = pd.read_csv('Advertising.csv') #reading data
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>Plot sales vs TV ads</h3></li></ul>
# </div>

# %%
plt.figure()
plt.scatter(data['TV'],data['sales'],c='black')
plt.xlabel("TV ads")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>Reshape and fit the data into simple linear regression</h3></li></ul>
# </div>

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
type(data['TV'])
# Out:
# pandas.core.series.Series

# %%
type(data[['TV']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['TV', 'radio', 'newspaper']]
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
data['TV'].values
# Out:
# array([230.1,  44.5,  17.2, 151.5, 180.8,   8.7,  57.5, 120.2,   8.6,
#        199.8,  66.1, 214.7,  23.8,  97.5, 204.1, 195.4,  67.8, 281.4,
#         69.2, 147.3, 218.4, 237.4,  13.2, 228.3,  62.3, 262.9, 142.9,
#        240.1, 248.8,  70.6, 292.9, 112.9,  97.2, 265.6,  95.7, 290.7,
#        266.9,  74.7,  43.1, 228. , 202.5, 177. , 293.6, 206.9,  25.1,
#        175.1,  89.7, 239.9, 227.2,  66.9, 199.8, 100.4, 216.4, 182.6,
#        262.7, 198.9,   7.3, 136.2, 210.8, 210.7,  53.5, 261.3, 239.3,
#        102.7, 131.1,  69. ,  31.5, 139.3, 237.4, 216.8, 199.1, 109.8,
#         26.8, 129.4, 213.4,  16.9,  27.5, 120.5,   5.4, 116. ,  76.4,
#        239.8,  75.3,  68.4, 213.5, 193.2,  76.3, 110.7,  88.3, 109.8,
#        134.3,  28.6, 217.7, 250.9, 107.4, 163.3, 197.6, 184.9, 289.7,
#        135.2, 222.4, 296.4, 280.2, 187.9, 238.2, 137.9,  25. ,  90.4,
#         13.1, 255.4, 225.8, 241.7, 175.7, 209.6,  78.2,  75.1, 139.2,
#         76.4, 125.7,  19.4, 141.3,  18.8, 224. , 123.1, 229.5,  87.2,
#          7.8,  80.2, 220.3,  59.6,   0.7, 265.2,   8.4, 219.8,  36.9,
#         48.3,  25.6, 273.7,  43. , 184.9,  73.4, 193.7, 220.5, 104.6,
#         96.2, 140.3, 240.1, 243.2,  38. ,  44.7, 280.7, 121. , 197.6,
#        171.3, 187.8,   4.1,  93.9, 149.8,  11.7, 131.7, 172.5,  85.7,
#        188.4, 163.5, 117.2, 234.5,  17.9, 206.8, 215.4, 284.3,  50. ,
#        164.5,  19.6, 168.4, 222.4, 276.9, 248.4, 170.2, 276.7, 165.6,
#        156.6, 218.5,  56.2, 287.6, 253.8, 205. , 139.5, 191.1, 286. ,
#         18.7,  39.5,  75.5,  17.2, 166.8, 149.7,  38.2,  94.2, 177. ,
#        283.6, 232.1])

# %%
data['TV'].values.reshape(-1,1)
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
#        [198.9],
#        [  7.3],
#        [136.2],
#        [210.8],
#        [210.7],
#        [ 53.5],
#        [261.3],
#        [239.3],
#        [102.7],
#        [131.1],
#        [ 69. ],
#        [ 31.5],
#        [139.3],
#        [237.4],
#        [216.8],
#        [199.1],
#        [109.8],
#        [ 26.8],
#        [129.4],
#        [213.4],
#        [ 16.9],
#        [ 27.5],
#        [120.5],
#        [  5.4],
#        [116. ],
#        [ 76.4],
#        [239.8],
#        [ 75.3],
#        [ 68.4],
#        [213.5],
#        [193.2],
#        [ 76.3],
#        [110.7],
#        [ 88.3],
#        [109.8],
#        [134.3],
#        [ 28.6],
#        [217.7],
#        [250.9],
#        [107.4],
#        [163.3],
#        [197.6],
#        [184.9],
#        [289.7],
#        [135.2],
#        [222.4],
#        [296.4],
#        [280.2],
#        [187.9],
#        [238.2],
#        [137.9],
#        [ 25. ],
#        [ 90.4],
#        [ 13.1],
#        [255.4],
#        [225.8],
#        [241.7],
#        [175.7],
#        [209.6],
#        [ 78.2],
#        [ 75.1],
#        [139.2],
#        [ 76.4],
#        [125.7],
#        [ 19.4],
#        [141.3],
#        [ 18.8],
#        [224. ],
#        [123.1],
#        [229.5],
#        [ 87.2],
#        [  7.8],
#        [ 80.2],
#        [220.3],
#        [ 59.6],
#        [  0.7],
#        [265.2],
#        [  8.4],
#        [219.8],
#        [ 36.9],
#        [ 48.3],
#        [ 25.6],
#        [273.7],
#        [ 43. ],
#        [184.9],
#        [ 73.4],
#        [193.7],
#        [220.5],
#        [104.6],
#        [ 96.2],
#        [140.3],
#        [240.1],
#        [243.2],
#        [ 38. ],
#        [ 44.7],
#        [280.7],
#        [121. ],
#        [197.6],
#        [171.3],
#        [187.8],
#        [  4.1],
#        [ 93.9],
#        [149.8],
#        [ 11.7],
#        [131.7],
#        [172.5],
#        [ 85.7],
#        [188.4],
#        [163.5],
#        [117.2],
#        [234.5],
#        [ 17.9],
#        [206.8],
#        [215.4],
#        [284.3],
#        [ 50. ],
#        [164.5],
#        [ 19.6],
#        [168.4],
#        [222.4],
#        [276.9],
#        [248.4],
#        [170.2],
#        [276.7],
#        [165.6],
#        [156.6],
#        [218.5],
#        [ 56.2],
#        [287.6],
#        [253.8],
#        [205. ],
#        [139.5],
#        [191.1],
#        [286. ],
#        [ 18.7],
#        [ 39.5],
#        [ 75.5],
#        [ 17.2],
#        [166.8],
#        [149.7],
#        [ 38.2],
#        [ 94.2],
#        [177. ],
#        [283.6],
#        [232.1]])

# %%
X = data['TV'].values.reshape(-1,1)
y = data['sales'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
X = data['TV'].values.reshape(-1,1)
y = data['sales'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
X = data['TV'].values.reshape(-1,1)
y = data['sales'].values.reshape(-1,1)
sgd_reg = SGDRegressor()
sgd_reg.fit(X, y)
# Out:
# c:\Workspace\MyProjects\MachineLearning\ml_venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor()

# %%
sgd_reg.score(X,y)
# Out:
# -1.4692691876429775e+25

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
X = data[['TV','radio', 'newspaper']].values
y = data['sales'].values.reshape(-1,1)
sgd_reg = SGDRegressor()
sgd_reg.fit(X, y)
# Out:
# c:\Workspace\MyProjects\MachineLearning\ml_venv\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDRegressor()

# %%
sgd_reg.score(X,y)
# Out:
# -7.388248865430772e+24

# %%
reg.coef_
# Out:
# array([[0.04753664]])

# %%
reg.intercept_
# Out:
# array([7.03259355])

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>R-squared value</h3></li></ul>
# </div>

# %%
X = data['TV'].values.reshape(-1,1)
y = data['sales'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X, y)
reg.score(X, y)
# Out:
# 0.611875050850071

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>Print co-efficient and intercept</h3></li></ul>
# </div>

# %%
data[['TV', 'radio', 'newspaper']]

print(reg.coef_)
print(reg.intercept_)
# Out:
# [[0.04753664]]
# [7.03259355]

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>Plot actual vs predicted values</h3></li></ul>
# </div>

# %%
y_pred = reg.predict(X)
plt.figure()
plt.scatter(data['TV'],data['sales'],c='yellow')
plt.plot(data['TV'],y_pred,c='blue',linewidth=2)
plt.xlabel("TV ads")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# <div style="background-color:##EDF9FF">
#  <ul><li><h3>Print statistical model</h3></li></ul>
# </div>

# %%
X = data['TV']
y = data['sales']
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Mon, 03 Mar 2025   Prob (F-statistic):           1.47e-42
# Time:                        11:41:45   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0326      0.458     15.360      0.000       6.130       7.935
# TV             0.0475      0.003     17.668      0.000       0.042       0.053
# ==============================================================================
# Omnibus:                        0.531   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.767   Jarque-Bera (JB):                0.669
# Skew:                          -0.089   Prob(JB):                        0.716
# Kurtosis:                       2.779   Cond. No.                         338.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <b> conclusion </b>: we have built a simple linear regression and its OLS model as well

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
X = data[['TV', 'radio', 'newspaper']].values
y = data['sales'].values.reshape(-1,1)
reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
reg.score(X,y)
# Out:
# 0.8972106381789522

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train.shape
# Out:
# (160, 3)

# %%
y_train.shape
# Out:
# (160, 1)

# %%
X_test.shape
# Out:
# (40, 3)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg
# Out:
# LinearRegression()

# %%
reg.score(X_train,y_train)
# Out:
# 0.9067114990146383

# %%
reg.score(X_test,y_test)
# Out:
# 0.8601145185017869

# %% [markdown]
# # Regularizing the model using Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import ElasticNet

# %%
rr = Ridge(alpha=1.0)

rr.fit(X_train, y_train)

pred_train_rr= rr.predict(X_train)

print(np.sqrt(mean_squared_error(y_train,pred_train_rr)))

print(r2_score(y_train, pred_train_rr))

pred_test_rr= rr.predict(X_test)

print(np.sqrt(mean_squared_error(y_test,pred_test_rr)))

print(r2_score(y_test, pred_test_rr))
# Out:
# 1.5513912348847623
# 0.906711498710047
# 2.098100822836412
# 0.8601174174619204

# %% [markdown]
# # Regularizing the model using Lasso Regression

# %%
model_lasso = Lasso(alpha=0.01)
model_lasso.fit(X_train, y_train)
pred_train_lasso= model_lasso.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_lasso)))
print(r2_score(y_train, pred_train_lasso))

pred_test_lasso= model_lasso.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_lasso)))
print(r2_score(y_test, pred_test_lasso))
# Out:
# 1.5513915473674675
# 0.906711461129525
# 2.0979444131772387
# 0.8601382726765995

# %% [markdown]
# # Regularizing the model using Elastic net

# %%
model_enet = ElasticNet(alpha = 0.01)

model_enet.fit(X_train, y_train)

pred_train_enet= model_enet.predict(X_train)

print(np.sqrt(mean_squared_error(y_train,pred_train_enet)))

print(r2_score(y_train, pred_train_enet))

pred_test_enet= model_enet.predict(X_test)

print(np.sqrt(mean_squared_error(y_test,pred_test_enet)))

print(r2_score(y_test, pred_test_enet))
# Out:
# 1.5513913288217345
# 0.9067114874127812
# 2.0980192167509344
# 0.8601282987769301

# %%
pred_train_enet
# Out:
# array([12.0426284 ,  9.22654053, 15.08773122, 16.357446  , 17.0758621 ,
#        13.36603466,  3.78850783, 12.08718229, 15.63004656,  8.68347921,
#        10.61234286, 19.36784845, 18.41222603, 15.30361669,  9.9999645 ,
#         8.19767931, 21.49419378, 14.15701546, 16.31716026,  8.72696717,
#        15.26966034, 12.4762075 , 13.72188095, 14.20504635, 18.32776057,
#        19.11951033, 20.32142866, 17.4939706 ,  9.3475113 , 11.75547954,
#        19.8586727 ,  9.91975837, 20.71049949, 23.06254657, 10.08435651,
#        17.13940512, 19.65142263, 18.43121402, 16.9173256 , 18.37694207,
#        17.10328599,  8.84074216,  9.94409583,  5.38714675,  3.58719342,
#        16.63375062, 12.58829584, 18.15886696, 11.77294237, 12.69589646,
#        13.7968666 ,  7.0148551 , 16.64683785,  9.79770085,  8.13529461,
#        15.71779992, 24.8318516 , 10.84563596, 21.15231382, 13.84740637,
#        10.64150192,  8.46651945, 12.41642747, 20.48895112, 10.50386072,
#        14.51704796, 16.33776689, 17.16886436, 13.18306572, 17.34141035,
#        21.2104321 ,  8.17484284, 16.09080706, 15.04214203,  8.81535218,
#        13.71321063, 16.42142299,  9.55370852, 14.35888301, 18.02670725,
#        20.93192073,  9.08428457, 20.33896673, 20.7261299 , 13.61777102,
#         4.47847842, 17.70190069, 11.9399332 , 11.09349023, 23.70756949,
#        11.93785083, 18.95161316, 20.86826118,  7.95745383,  5.44129122,
#        14.30431493, 15.58823449,  4.47389731, 15.00854333, 17.27129774,
#         6.94199025, 17.41259788, 16.73758058, 12.79370898,  7.8961245 ,
#        12.5756097 , 14.43243018, 14.87997294, 21.52188357, 18.09614724,
#         8.70775073, 11.86258738, 23.16670575, 10.06539431, 19.25153051,
#        20.05054385,  9.86209709, 22.43472422,  7.51648546, 19.34840331,
#        15.58080283,  9.9055873 , 11.34052278, 11.12063012,  6.54542985,
#        19.94678449,  7.54057836, 19.2436885 , 17.73505363, 23.3421448 ,
#         9.1735377 , 17.08858742, 10.25079177,  9.61586353, 13.07406932,
#        12.57399037, 18.67319401, 10.62004661, 13.92748257, 15.34991056,
#        13.88372927, 14.38985648, 18.46662777, 13.54233131, 12.81488452,
#        20.4784379 , 22.0337638 ,  9.57190017, 11.73899584, 17.77660097,
#        15.73240784, 23.48571736, 14.51633407, 12.35521116, 14.70213523,
#        12.02622323,  4.48031965,  6.51771525, 21.7928225 ,  7.77104151])
